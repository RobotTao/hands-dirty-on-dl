# %% [markdown]
# # AlexNet
#
# 在2012年之前，计算机视觉领域长期依赖手工设计特征（如SIFT、HOG）和传统机器学习模型（如SVM），这些方法在复杂任务（如大规模图像分类）上性能有限。随着ImageNet数据集的发布（包含百万级标注图像），传统方法的瓶颈愈发明显——模型难以从海量数据中自动学习高阶特征。AlexNet在2012年ImageNet图像分类竞赛（ILSVRC）中以15.3%的Top-5错误率夺冠，远超第二名（26.2%），首次证明了深度卷积神经网络（CNN）在大规模视觉任务中的统治力，成为深度学习革命的里程碑。
#
# 核心创新点：
#
# * ReLU激活函数：取代传统的Sigmoid/Tanh，缓解梯度消失问题，加速训练收敛。
# * GPU并行训练：首次利用双GPU（GTX 580）并行计算，突破算力限制，推动硬件与深度学习的结合。
# * Dropout正则化：在全连接层随机丢弃神经元，减少过拟合，提升泛化能力。
# * 数据增强：通过裁剪、翻转、颜色扰动扩充数据，降低对训练数据的依赖。
# * 局部响应归一化（LRN）：增强特征间竞争，后被批量归一化（BatchNorm）取代，但启发了归一化层设计。
# * 重叠池化（Overlapping Pooling）：提升特征提取的丰富性，这一操作已经被non-overlapping pooling取代。
# * 架构模板化：确立“卷积层→池化层→全连接层”的堆叠范式，后续模型（VGG、ResNet等）均沿袭此框架。
# * 大数据驱动：证明数据规模与模型深度的正相关性，奠定“数据+算力+算法”的AI发展范式。
#
# AlexNet不仅是技术突破，更是研究范式的转折点。它证明：通过数据与算力放大模型能力，AI可以解决此前被认为“不可能”的任务。其影响力远超计算机视觉，重塑了整个AI领域的发展轨迹，至今仍是深度学习课程与工业实践的“第一课”。
#
# ![alt text](resources/alex_architecture.png "Title")

# %%
# 自动重新加载外部module，使得修改代码之后无需重新import
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

import time

from hdd.device.utils import get_device
from hdd.dataset.imagenette_in_memory import ImagenetteInMemory, get_mean_and_std

import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms

# 设置训练数据的路径
DATA_ROOT = "~/workspace/hands-dirty-on-dl/dataset"
DEVICE = get_device(["cuda", "cpu"])
TENSORBOARD_ROOT = "~/workspace/hands-dirty-on-dl/dataset"
print("Use device: ", DEVICE)
# Out:
# Use device:  cuda

# %% [markdown]
# ## Imagenette数据集
#
# AlexNet是在ImageNet上进行训练的，由于资源有限，我们在其子集上进行小规模尝试，[Imagenette](https://github.com/fastai/imagenette)是一个只包含10类的比较容易分类的小数据集。具体类别如下图所示：
# ![alt text](resources/imagenette_samples.png "Title")

# %%
# 计算Imagenette的均值方差，用如下代码
# train_dataest = ImagenetteInMemory(
#     root=DATA_ROOT,
#     split="train",
#     size="full",
#     download=True,
#     transform=transforms.Compose([transforms.ToTensor()]),
# )
# mean, std = get_mean_and_std(train_dataest)

# 我们跳过计算，直接给出结果
TRAIN_MEAN = [0.4625, 0.4580, 0.4295]
TRAIN_STD = [0.2452, 0.2390, 0.2469]
train_dataset_transforms = transforms.Compose(
    [
        transforms.Resize(296),
        transforms.RandomRotation(10),
        transforms.RandomCrop(224),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize(mean=TRAIN_MEAN, std=TRAIN_STD),
    ]
)
val_dataset_transforms = transforms.Compose(
    [
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize(mean=TRAIN_MEAN, std=TRAIN_STD),
    ]
)

BATCH_SIZE = 64
train_dataloader = torch.utils.data.DataLoader(
    ImagenetteInMemory(
        root=DATA_ROOT,
        split="train",
        size="full",
        download=True,
        transform=train_dataset_transforms,
    ),
    batch_size=BATCH_SIZE,
    shuffle=True,
    num_workers=8,
    pin_memory=True,
)
val_dataloader = torch.utils.data.DataLoader(
    ImagenetteInMemory(
        root=DATA_ROOT,
        split="val",
        size="full",
        download=True,
        transform=val_dataset_transforms,
    ),
    batch_size=BATCH_SIZE,
    shuffle=False,
    num_workers=8,
    pin_memory=True,
)
print("Basic Info of train dataaset ", train_dataloader.dataset)
print("Basic Info of val dataset ", val_dataloader.dataset)
# Out:
# Basic Info of train dataaset  Dataset ImagenetteInMemory
#     Number of datapoints: 9469
#     Root location: /home/tf/workspace/hands-dirty-on-dl/dataset
#     StandardTransform
# Transform: Compose(
#                Resize(size=296, interpolation=bilinear, max_size=None, antialias=True)
#                RandomRotation(degrees=[-10.0, 10.0], interpolation=nearest, expand=False, fill=0)
#                RandomCrop(size=(224, 224), padding=None)
#                RandomHorizontalFlip(p=0.5)
#                ToTensor()
#                Normalize(mean=[0.4625, 0.458, 0.4295], std=[0.2452, 0.239, 0.2469])
#            )
# Basic Info of val dataset  Dataset ImagenetteInMemory
#     Number of datapoints: 3925
#     Root location: /home/tf/workspace/hands-dirty-on-dl/dataset
#     StandardTransform
# Transform: Compose(
#                Resize(size=256, interpolation=bilinear, max_size=None, antialias=True)
#                CenterCrop(size=(224, 224))
#                ToTensor()
#                Normalize(mean=[0.4625, 0.458, 0.4295], std=[0.2452, 0.239, 0.2469])
#            )

# %%
from hdd.models.cnn.alexnet import AlexNet
from hdd.train.early_stopping import EarlyStoppingInMem
from hdd.train.classification_utils import naive_train_classification_model

net = AlexNet(num_classes=10, dropout=0.5, add_norm_layer=True).to(DEVICE)
criteria = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(net.parameters(), lr=0.01, momentum=0.9, weight_decay=1e-2)
scheduler = torch.optim.lr_scheduler.StepLR(
    optimizer, step_size=15, gamma=0.5, last_epoch=-1
)
early_stopper = EarlyStoppingInMem(patience=15, verbose=False)
max_epochs = 150

train_statistics_with_norm = naive_train_classification_model(
    net,
    criteria,
    max_epochs,
    train_dataloader,
    val_dataloader,
    DEVICE,
    optimizer,
    scheduler,
    early_stopper,
)
# Out:
# Epoch: 1/150 Train Loss: 1.8784 Accuracy: 0.3371 Time: 3.94968  | Val Loss: 1.9061 Accuracy: 0.3918
# Epoch: 2/150 Train Loss: 1.4719 Accuracy: 0.5052 Time: 4.12303  | Val Loss: 1.7843 Accuracy: 0.4339
# Epoch: 3/150 Train Loss: 1.2993 Accuracy: 0.5743 Time: 3.95677  | Val Loss: 1.2857 Accuracy: 0.5758
# Epoch: 4/150 Train Loss: 1.2208 Accuracy: 0.6015 Time: 3.83922  | Val Loss: 1.1351 Accuracy: 0.6387
# Epoch: 5/150 Train Loss: 1.1542 Accuracy: 0.6259 Time: 4.14857  | Val Loss: 1.0331 Accuracy: 0.6637
# Epoch: 6/150 Train Loss: 1.0872 Accuracy: 0.6475 Time: 4.15409  | Val Loss: 1.1059 Accuracy: 0.6507
# Epoch: 7/150 Train Loss: 1.0429 Accuracy: 0.6624 Time: 4.21420  | Val Loss: 1.3344 Accuracy: 0.6043
# Epoch: 8/150 Train Loss: 1.0189 Accuracy: 0.6702 Time: 3.95794  | Val Loss: 1.2044 Accuracy: 0.5926
# Epoch: 9/150 Train Loss: 1.0210 Accuracy: 0.6653 Time: 4.14402  | Val Loss: 0.9504 Accuracy: 0.6904
# Epoch: 10/150 Train Loss: 0.9500 Accuracy: 0.6950 Time: 3.85119  | Val Loss: 1.0097 Accuracy: 0.6841
# Epoch: 11/150 Train Loss: 0.9121 Accuracy: 0.7058 Time: 3.91481  | Val Loss: 1.1999 Accuracy: 0.6135
# Epoch: 12/150 Train Loss: 0.9097 Accuracy: 0.7057 Time: 4.08428  | Val Loss: 1.0685 Accuracy: 0.6573
# Epoch: 13/150 Train Loss: 0.9041 Accuracy: 0.7112 Time: 4.05703  | Val Loss: 1.4524 Accuracy: 0.5939
# Epoch: 14/150 Train Loss: 0.8922 Accuracy: 0.7169 Time: 4.18165  | Val Loss: 0.9861 Accuracy: 0.6938
# Epoch: 15/150 Train Loss: 0.8790 Accuracy: 0.7172 Time: 4.06828  | Val Loss: 1.0451 Accuracy: 0.6647
# Epoch: 16/150 Train Loss: 0.7364 Accuracy: 0.7687 Time: 4.12889  | Val Loss: 0.7050 Accuracy: 0.7722
# Epoch: 17/150 Train Loss: 0.7099 Accuracy: 0.7697 Time: 4.39206  | Val Loss: 0.8345 Accuracy: 0.7381
# Epoch: 18/150 Train Loss: 0.7074 Accuracy: 0.7777 Time: 4.11406  | Val Loss: 0.7271 Accuracy: 0.7712
# Epoch: 19/150 Train Loss: 0.6866 Accuracy: 0.7761 Time: 4.60726  | Val Loss: 0.9873 Accuracy: 0.6950
# Epoch: 20/150 Train Loss: 0.7004 Accuracy: 0.7777 Time: 4.51685  | Val Loss: 0.8633 Accuracy: 0.7330
# Epoch: 21/150 Train Loss: 0.6825 Accuracy: 0.7808 Time: 3.95080  | Val Loss: 0.9719 Accuracy: 0.6961
# Epoch: 22/150 Train Loss: 0.6817 Accuracy: 0.7838 Time: 4.08946  | Val Loss: 0.7190 Accuracy: 0.7674
# Epoch: 23/150 Train Loss: 0.6958 Accuracy: 0.7773 Time: 4.73304  | Val Loss: 0.9581 Accuracy: 0.7175
# Epoch: 24/150 Train Loss: 0.6717 Accuracy: 0.7851 Time: 4.07154  | Val Loss: 1.6199 Accuracy: 0.5468
# Epoch: 25/150 Train Loss: 0.6658 Accuracy: 0.7873 Time: 4.05328  | Val Loss: 0.8508 Accuracy: 0.7287
# Epoch: 26/150 Train Loss: 0.6467 Accuracy: 0.7926 Time: 4.43563  | Val Loss: 0.8465 Accuracy: 0.7401
# Epoch: 27/150 Train Loss: 0.6388 Accuracy: 0.7931 Time: 4.06609  | Val Loss: 0.9259 Accuracy: 0.7047
# Epoch: 28/150 Train Loss: 0.6521 Accuracy: 0.7918 Time: 3.96845  | Val Loss: 0.7900 Accuracy: 0.7511
# Epoch: 29/150 Train Loss: 0.6464 Accuracy: 0.7979 Time: 3.92788  | Val Loss: 0.7419 Accuracy: 0.7654
# Epoch: 30/150 Train Loss: 0.6344 Accuracy: 0.7963 Time: 3.96748  | Val Loss: 1.0237 Accuracy: 0.6731
# Epoch: 31/150 Train Loss: 0.5138 Accuracy: 0.8362 Time: 3.94930  | Val Loss: 0.5505 Accuracy: 0.8206
# Epoch: 32/150 Train Loss: 0.4793 Accuracy: 0.8480 Time: 3.86525  | Val Loss: 0.6078 Accuracy: 0.8140
# Epoch: 33/150 Train Loss: 0.4698 Accuracy: 0.8495 Time: 4.06018  | Val Loss: 0.6043 Accuracy: 0.8117
# Epoch: 34/150 Train Loss: 0.4572 Accuracy: 0.8581 Time: 3.89083  | Val Loss: 0.4931 Accuracy: 0.8492
# Epoch: 35/150 Train Loss: 0.4602 Accuracy: 0.8545 Time: 3.93360  | Val Loss: 0.6196 Accuracy: 0.8082
# Epoch: 36/150 Train Loss: 0.4592 Accuracy: 0.8510 Time: 3.85445  | Val Loss: 0.5501 Accuracy: 0.8255
# Epoch: 37/150 Train Loss: 0.4490 Accuracy: 0.8555 Time: 4.23831  | Val Loss: 0.6795 Accuracy: 0.7913
# Epoch: 38/150 Train Loss: 0.4536 Accuracy: 0.8560 Time: 3.77590  | Val Loss: 0.6529 Accuracy: 0.8041
# Epoch: 39/150 Train Loss: 0.4461 Accuracy: 0.8579 Time: 3.86581  | Val Loss: 0.6705 Accuracy: 0.7913
# Epoch: 40/150 Train Loss: 0.4501 Accuracy: 0.8543 Time: 3.96453  | Val Loss: 0.7139 Accuracy: 0.7776
# Epoch: 41/150 Train Loss: 0.4561 Accuracy: 0.8539 Time: 3.87918  | Val Loss: 0.6299 Accuracy: 0.8061
# Epoch: 42/150 Train Loss: 0.4324 Accuracy: 0.8599 Time: 3.85833  | Val Loss: 0.6237 Accuracy: 0.8018
# Epoch: 43/150 Train Loss: 0.4376 Accuracy: 0.8599 Time: 3.83637  | Val Loss: 0.6737 Accuracy: 0.7878
# Epoch: 44/150 Train Loss: 0.4294 Accuracy: 0.8605 Time: 3.83048  | Val Loss: 0.5080 Accuracy: 0.8431
# Epoch: 45/150 Train Loss: 0.4299 Accuracy: 0.8565 Time: 3.85175  | Val Loss: 0.6274 Accuracy: 0.8025
# Epoch: 46/150 Train Loss: 0.3263 Accuracy: 0.8989 Time: 3.89833  | Val Loss: 0.4550 Accuracy: 0.8576
# Epoch: 47/150 Train Loss: 0.2953 Accuracy: 0.9062 Time: 3.90248  | Val Loss: 0.4232 Accuracy: 0.8629
# Epoch: 48/150 Train Loss: 0.2752 Accuracy: 0.9142 Time: 3.82150  | Val Loss: 0.4556 Accuracy: 0.8586
# Epoch: 49/150 Train Loss: 0.2703 Accuracy: 0.9160 Time: 3.81853  | Val Loss: 0.4542 Accuracy: 0.8596
# Epoch: 50/150 Train Loss: 0.2710 Accuracy: 0.9151 Time: 3.85672  | Val Loss: 0.5667 Accuracy: 0.8298
# Epoch: 51/150 Train Loss: 0.2730 Accuracy: 0.9158 Time: 3.83317  | Val Loss: 0.4999 Accuracy: 0.8420
# Epoch: 52/150 Train Loss: 0.2517 Accuracy: 0.9224 Time: 3.86894  | Val Loss: 0.4852 Accuracy: 0.8504
# Epoch: 53/150 Train Loss: 0.2557 Accuracy: 0.9192 Time: 3.89162  | Val Loss: 0.5569 Accuracy: 0.8318
# Epoch: 54/150 Train Loss: 0.2781 Accuracy: 0.9129 Time: 3.80426  | Val Loss: 0.5844 Accuracy: 0.8293
# Epoch: 55/150 Train Loss: 0.2611 Accuracy: 0.9189 Time: 3.83963  | Val Loss: 0.5209 Accuracy: 0.8410
# Epoch: 56/150 Train Loss: 0.2563 Accuracy: 0.9210 Time: 3.79345  | Val Loss: 0.5322 Accuracy: 0.8479
# Epoch: 57/150 Train Loss: 0.2490 Accuracy: 0.9217 Time: 3.84916  | Val Loss: 0.5755 Accuracy: 0.8288
# Epoch: 58/150 Train Loss: 0.2631 Accuracy: 0.9160 Time: 3.80719  | Val Loss: 0.5472 Accuracy: 0.8344
# Epoch: 59/150 Train Loss: 0.2424 Accuracy: 0.9244 Time: 3.87615  | Val Loss: 0.6538 Accuracy: 0.8206
# Epoch: 60/150 Train Loss: 0.2519 Accuracy: 0.9207 Time: 3.83052  | Val Loss: 0.6053 Accuracy: 0.8229
# Epoch: 61/150 Train Loss: 0.1755 Accuracy: 0.9511 Time: 3.99750  | Val Loss: 0.4254 Accuracy: 0.8729
# Epoch: 62/150 Train Loss: 0.1496 Accuracy: 0.9562 Time: 3.80938  | Val Loss: 0.4063 Accuracy: 0.8757
# Epoch: 63/150 Train Loss: 0.1475 Accuracy: 0.9582 Time: 3.84851  | Val Loss: 0.3976 Accuracy: 0.8754
# Epoch: 64/150 Train Loss: 0.1416 Accuracy: 0.9605 Time: 3.83203  | Val Loss: 0.4309 Accuracy: 0.8736
# Epoch: 65/150 Train Loss: 0.1229 Accuracy: 0.9659 Time: 3.83732  | Val Loss: 0.4404 Accuracy: 0.8696
# Epoch: 66/150 Train Loss: 0.1209 Accuracy: 0.9673 Time: 3.79655  | Val Loss: 0.4158 Accuracy: 0.8698
# Epoch: 67/150 Train Loss: 0.1295 Accuracy: 0.9637 Time: 3.93019  | Val Loss: 0.4062 Accuracy: 0.8782
# Epoch: 68/150 Train Loss: 0.1296 Accuracy: 0.9612 Time: 3.88785  | Val Loss: 0.4530 Accuracy: 0.8688
# Epoch: 69/150 Train Loss: 0.1257 Accuracy: 0.9645 Time: 3.83635  | Val Loss: 0.4475 Accuracy: 0.8670
# Epoch: 70/150 Train Loss: 0.1173 Accuracy: 0.9674 Time: 3.88833  | Val Loss: 0.4267 Accuracy: 0.8716
# Epoch: 71/150 Train Loss: 0.1231 Accuracy: 0.9662 Time: 3.82087  | Val Loss: 0.4262 Accuracy: 0.8749
# Epoch: 72/150 Train Loss: 0.1202 Accuracy: 0.9657 Time: 3.88389  | Val Loss: 0.5225 Accuracy: 0.8476
# Epoch: 73/150 Train Loss: 0.1175 Accuracy: 0.9677 Time: 3.82118  | Val Loss: 0.4764 Accuracy: 0.8586
# Epoch: 74/150 Train Loss: 0.1182 Accuracy: 0.9668 Time: 3.92580  | Val Loss: 0.4084 Accuracy: 0.8724
# Epoch: 75/150 Train Loss: 0.1118 Accuracy: 0.9700 Time: 3.91070  | Val Loss: 0.4456 Accuracy: 0.8741
# Epoch: 76/150 Train Loss: 0.0861 Accuracy: 0.9789 Time: 3.89645  | Val Loss: 0.3955 Accuracy: 0.8792
# Epoch: 77/150 Train Loss: 0.0723 Accuracy: 0.9825 Time: 3.87864  | Val Loss: 0.3956 Accuracy: 0.8800
# Epoch: 78/150 Train Loss: 0.0740 Accuracy: 0.9817 Time: 3.81384  | Val Loss: 0.3995 Accuracy: 0.8818
# Epoch: 79/150 Train Loss: 0.0721 Accuracy: 0.9820 Time: 3.92856  | Val Loss: 0.3834 Accuracy: 0.8892
# Epoch: 80/150 Train Loss: 0.0736 Accuracy: 0.9815 Time: 3.83231  | Val Loss: 0.3842 Accuracy: 0.8848
# Epoch: 81/150 Train Loss: 0.0636 Accuracy: 0.9851 Time: 3.88355  | Val Loss: 0.4143 Accuracy: 0.8782
# Epoch: 82/150 Train Loss: 0.0670 Accuracy: 0.9849 Time: 3.85835  | Val Loss: 0.3839 Accuracy: 0.8825
# Epoch: 83/150 Train Loss: 0.0643 Accuracy: 0.9854 Time: 3.92722  | Val Loss: 0.3786 Accuracy: 0.8879
# Epoch: 84/150 Train Loss: 0.0633 Accuracy: 0.9869 Time: 3.86767  | Val Loss: 0.3805 Accuracy: 0.8831
# Epoch: 85/150 Train Loss: 0.0647 Accuracy: 0.9861 Time: 3.88731  | Val Loss: 0.3867 Accuracy: 0.8825
# Epoch: 86/150 Train Loss: 0.0640 Accuracy: 0.9854 Time: 3.77664  | Val Loss: 0.3769 Accuracy: 0.8843
# Epoch: 87/150 Train Loss: 0.0603 Accuracy: 0.9874 Time: 3.82148  | Val Loss: 0.3978 Accuracy: 0.8856
# Epoch: 88/150 Train Loss: 0.0531 Accuracy: 0.9897 Time: 3.86333  | Val Loss: 0.3984 Accuracy: 0.8833
# Epoch: 89/150 Train Loss: 0.0578 Accuracy: 0.9873 Time: 4.01583  | Val Loss: 0.3871 Accuracy: 0.8828
# Epoch: 90/150 Train Loss: 0.0622 Accuracy: 0.9857 Time: 3.80903  | Val Loss: 0.4210 Accuracy: 0.8782
# Epoch: 91/150 Train Loss: 0.0529 Accuracy: 0.9886 Time: 3.87142  | Val Loss: 0.3793 Accuracy: 0.8864
# Epoch: 92/150 Train Loss: 0.0483 Accuracy: 0.9911 Time: 3.81899  | Val Loss: 0.3699 Accuracy: 0.8892
# Epoch: 93/150 Train Loss: 0.0506 Accuracy: 0.9905 Time: 3.88900  | Val Loss: 0.3695 Accuracy: 0.8879
# Epoch: 94/150 Train Loss: 0.0469 Accuracy: 0.9906 Time: 3.90940  | Val Loss: 0.3939 Accuracy: 0.8846
# Epoch: 95/150 Train Loss: 0.0442 Accuracy: 0.9922 Time: 3.85927  | Val Loss: 0.3786 Accuracy: 0.8859
# Epoch: 96/150 Train Loss: 0.0440 Accuracy: 0.9920 Time: 3.82666  | Val Loss: 0.3821 Accuracy: 0.8854
# Epoch: 97/150 Train Loss: 0.0430 Accuracy: 0.9928 Time: 3.87005  | Val Loss: 0.3761 Accuracy: 0.8871
# Epoch: 98/150 Train Loss: 0.0434 Accuracy: 0.9924 Time: 3.89678  | Val Loss: 0.3799 Accuracy: 0.8854
# Epoch: 99/150 Train Loss: 0.0401 Accuracy: 0.9932 Time: 3.83616  | Val Loss: 0.3744 Accuracy: 0.8856
# Epoch: 100/150 Train Loss: 0.0407 Accuracy: 0.9920 Time: 3.81662  | Val Loss: 0.3735 Accuracy: 0.8910
# Epoch: 101/150 Train Loss: 0.0394 Accuracy: 0.9939 Time: 3.83986  | Val Loss: 0.3719 Accuracy: 0.8879
# Epoch: 102/150 Train Loss: 0.0425 Accuracy: 0.9924 Time: 3.87205  | Val Loss: 0.3703 Accuracy: 0.8894
# Epoch: 103/150 Train Loss: 0.0400 Accuracy: 0.9935 Time: 3.95145  | Val Loss: 0.3747 Accuracy: 0.8889
# Epoch: 104/150 Train Loss: 0.0410 Accuracy: 0.9932 Time: 3.80745  | Val Loss: 0.3750 Accuracy: 0.8884
# Epoch: 105/150 Train Loss: 0.0393 Accuracy: 0.9933 Time: 3.90009  | Val Loss: 0.3778 Accuracy: 0.8912
# Epoch: 106/150 Train Loss: 0.0404 Accuracy: 0.9929 Time: 3.86024  | Val Loss: 0.3777 Accuracy: 0.8892
# Epoch: 107/150 Train Loss: 0.0373 Accuracy: 0.9944 Time: 3.84975  | Val Loss: 0.3689 Accuracy: 0.8879
# Epoch: 108/150 Train Loss: 0.0386 Accuracy: 0.9937 Time: 3.86075  | Val Loss: 0.3698 Accuracy: 0.8904
# Epoch: 109/150 Train Loss: 0.0343 Accuracy: 0.9950 Time: 3.86727  | Val Loss: 0.3626 Accuracy: 0.8899
# Epoch: 110/150 Train Loss: 0.0343 Accuracy: 0.9950 Time: 3.82099  | Val Loss: 0.3732 Accuracy: 0.8869
# Epoch: 111/150 Train Loss: 0.0381 Accuracy: 0.9931 Time: 3.78503  | Val Loss: 0.3729 Accuracy: 0.8876
# Epoch: 112/150 Train Loss: 0.0365 Accuracy: 0.9944 Time: 3.86492  | Val Loss: 0.3616 Accuracy: 0.8910
# Epoch: 113/150 Train Loss: 0.0332 Accuracy: 0.9948 Time: 3.89288  | Val Loss: 0.3677 Accuracy: 0.8879
# Epoch: 114/150 Train Loss: 0.0347 Accuracy: 0.9950 Time: 3.79370  | Val Loss: 0.3678 Accuracy: 0.8910
# Epoch: 115/150 Train Loss: 0.0339 Accuracy: 0.9950 Time: 3.84282  | Val Loss: 0.3700 Accuracy: 0.8869
# Epoch: 116/150 Train Loss: 0.0339 Accuracy: 0.9956 Time: 3.81827  | Val Loss: 0.3589 Accuracy: 0.8907
# Epoch: 117/150 Train Loss: 0.0324 Accuracy: 0.9957 Time: 3.81194  | Val Loss: 0.3612 Accuracy: 0.8892
# Epoch: 118/150 Train Loss: 0.0335 Accuracy: 0.9943 Time: 3.83774  | Val Loss: 0.3630 Accuracy: 0.8887
# Epoch: 119/150 Train Loss: 0.0334 Accuracy: 0.9946 Time: 3.86597  | Val Loss: 0.3700 Accuracy: 0.8899
# Epoch: 120/150 Train Loss: 0.0335 Accuracy: 0.9956 Time: 3.84705  | Val Loss: 0.3708 Accuracy: 0.8879
# Epoch: 121/150 Train Loss: 0.0345 Accuracy: 0.9944 Time: 3.84591  | Val Loss: 0.3680 Accuracy: 0.8902
# Epoch: 122/150 Train Loss: 0.0308 Accuracy: 0.9949 Time: 3.82726  | Val Loss: 0.3636 Accuracy: 0.8882
# Epoch: 123/150 Train Loss: 0.0308 Accuracy: 0.9961 Time: 3.86863  | Val Loss: 0.3626 Accuracy: 0.8894
# Epoch: 124/150 Train Loss: 0.0321 Accuracy: 0.9955 Time: 3.89603  | Val Loss: 0.3644 Accuracy: 0.8874
# Epoch: 125/150 Train Loss: 0.0302 Accuracy: 0.9962 Time: 3.86811  | Val Loss: 0.3657 Accuracy: 0.8892
# Epoch: 126/150 Train Loss: 0.0300 Accuracy: 0.9957 Time: 3.85237  | Val Loss: 0.3702 Accuracy: 0.8843
# Epoch: 127/150 Train Loss: 0.0312 Accuracy: 0.9963 Time: 3.95113  | Val Loss: 0.3656 Accuracy: 0.8876
# Epoch: 128/150 Train Loss: 0.0311 Accuracy: 0.9960 Time: 3.95993  | Val Loss: 0.3662 Accuracy: 0.8882
# Epoch: 129/150 Train Loss: 0.0318 Accuracy: 0.9955 Time: 3.79606  | Val Loss: 0.3657 Accuracy: 0.8879
# Epoch: 130/150 Train Loss: 0.0314 Accuracy: 0.9943 Time: 3.90104  | Val Loss: 0.3682 Accuracy: 0.8887
# Epoch: 131/150 Train Loss: 0.0318 Accuracy: 0.9943 Time: 3.82799  | Val Loss: 0.3703 Accuracy: 0.8856
# Early stop at epoch 131!

# %%
# Train network without batch normalization
net_without_bn = AlexNet(num_classes=10, dropout=0.5, add_norm_layer=False).to(DEVICE)
criteria = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(
    net_without_bn.parameters(), lr=0.01, momentum=0.9, weight_decay=1e-2
)
scheduler = torch.optim.lr_scheduler.StepLR(
    optimizer, step_size=15, gamma=0.5, last_epoch=-1
)
early_stopper = EarlyStoppingInMem(patience=15, verbose=False)
max_epochs = 150

train_statistics_without_norm = naive_train_classification_model(
    net_without_bn,
    criteria,
    max_epochs,
    train_dataloader,
    val_dataloader,
    DEVICE,
    optimizer,
    scheduler,
    early_stopper,
    verbose=True,
)
# Out:
# Epoch: 1/150 Train Loss: 2.2915 Accuracy: 0.1213 Time: 4.78137  | Val Loss: 2.2627 Accuracy: 0.1906
# Epoch: 2/150 Train Loss: 2.1807 Accuracy: 0.2061 Time: 3.96096  | Val Loss: 2.0810 Accuracy: 0.2341
# Epoch: 3/150 Train Loss: 2.0718 Accuracy: 0.2369 Time: 4.00623  | Val Loss: 1.9818 Accuracy: 0.2915
# Epoch: 4/150 Train Loss: 2.0194 Accuracy: 0.2749 Time: 3.91538  | Val Loss: 1.9361 Accuracy: 0.3225
# Epoch: 5/150 Train Loss: 1.9847 Accuracy: 0.2950 Time: 3.95778  | Val Loss: 1.9256 Accuracy: 0.3389
# Epoch: 6/150 Train Loss: 1.9684 Accuracy: 0.3007 Time: 4.02134  | Val Loss: 1.8865 Accuracy: 0.3531
# Epoch: 7/150 Train Loss: 1.9282 Accuracy: 0.3141 Time: 3.90479  | Val Loss: 1.8888 Accuracy: 0.3299
# Epoch: 8/150 Train Loss: 1.9041 Accuracy: 0.3241 Time: 3.85574  | Val Loss: 1.9081 Accuracy: 0.3149
# Epoch: 9/150 Train Loss: 1.8809 Accuracy: 0.3364 Time: 3.88946  | Val Loss: 1.9499 Accuracy: 0.3121
# Epoch: 10/150 Train Loss: 1.8002 Accuracy: 0.3695 Time: 3.88374  | Val Loss: 1.7838 Accuracy: 0.3738
# Epoch: 11/150 Train Loss: 1.7370 Accuracy: 0.4038 Time: 3.86495  | Val Loss: 1.6249 Accuracy: 0.4362
# Epoch: 12/150 Train Loss: 1.6588 Accuracy: 0.4305 Time: 3.92945  | Val Loss: 1.5776 Accuracy: 0.4632
# Epoch: 13/150 Train Loss: 1.6240 Accuracy: 0.4490 Time: 3.93188  | Val Loss: 1.4867 Accuracy: 0.5096
# Epoch: 14/150 Train Loss: 1.5462 Accuracy: 0.4853 Time: 3.94805  | Val Loss: 1.4742 Accuracy: 0.5101
# Epoch: 15/150 Train Loss: 1.4736 Accuracy: 0.5072 Time: 3.86382  | Val Loss: 1.4687 Accuracy: 0.5106
# Epoch: 16/150 Train Loss: 1.3538 Accuracy: 0.5505 Time: 3.95740  | Val Loss: 1.3701 Accuracy: 0.5432
# Epoch: 17/150 Train Loss: 1.3149 Accuracy: 0.5599 Time: 3.90825  | Val Loss: 1.2235 Accuracy: 0.5946
# Epoch: 18/150 Train Loss: 1.2955 Accuracy: 0.5712 Time: 3.91870  | Val Loss: 1.1637 Accuracy: 0.6150
# Epoch: 19/150 Train Loss: 1.2637 Accuracy: 0.5839 Time: 4.17197  | Val Loss: 1.1790 Accuracy: 0.6130
# Epoch: 20/150 Train Loss: 1.2415 Accuracy: 0.5924 Time: 3.93388  | Val Loss: 1.2447 Accuracy: 0.5865
# Epoch: 21/150 Train Loss: 1.2041 Accuracy: 0.6065 Time: 3.96007  | Val Loss: 1.0649 Accuracy: 0.6484
# Epoch: 22/150 Train Loss: 1.1879 Accuracy: 0.6163 Time: 3.91547  | Val Loss: 1.0301 Accuracy: 0.6647
# Epoch: 23/150 Train Loss: 1.1991 Accuracy: 0.6057 Time: 3.99724  | Val Loss: 1.0904 Accuracy: 0.6487
# Epoch: 24/150 Train Loss: 1.1825 Accuracy: 0.6157 Time: 3.96417  | Val Loss: 1.0599 Accuracy: 0.6645
# Epoch: 25/150 Train Loss: 1.1454 Accuracy: 0.6280 Time: 3.94478  | Val Loss: 1.0745 Accuracy: 0.6504
# Epoch: 26/150 Train Loss: 1.1218 Accuracy: 0.6374 Time: 3.86094  | Val Loss: 1.1095 Accuracy: 0.6413
# Epoch: 27/150 Train Loss: 1.1320 Accuracy: 0.6321 Time: 4.02860  | Val Loss: 1.0098 Accuracy: 0.6746
# Epoch: 28/150 Train Loss: 1.0964 Accuracy: 0.6438 Time: 3.86978  | Val Loss: 1.0045 Accuracy: 0.6724
# Epoch: 29/150 Train Loss: 1.1074 Accuracy: 0.6386 Time: 3.95461  | Val Loss: 0.9874 Accuracy: 0.6775
# Epoch: 30/150 Train Loss: 1.0763 Accuracy: 0.6555 Time: 3.85517  | Val Loss: 1.0043 Accuracy: 0.6652
# Epoch: 31/150 Train Loss: 0.9768 Accuracy: 0.6780 Time: 3.99464  | Val Loss: 0.9155 Accuracy: 0.7228
# Epoch: 32/150 Train Loss: 0.9527 Accuracy: 0.6833 Time: 3.93956  | Val Loss: 0.8456 Accuracy: 0.7335
# Epoch: 33/150 Train Loss: 0.9185 Accuracy: 0.7000 Time: 4.06636  | Val Loss: 0.8815 Accuracy: 0.7192
# Epoch: 34/150 Train Loss: 0.9160 Accuracy: 0.7065 Time: 3.94208  | Val Loss: 0.9351 Accuracy: 0.7093
# Epoch: 35/150 Train Loss: 0.8968 Accuracy: 0.7118 Time: 4.02579  | Val Loss: 0.9240 Accuracy: 0.7001
# Epoch: 36/150 Train Loss: 0.8999 Accuracy: 0.7103 Time: 3.93105  | Val Loss: 0.8287 Accuracy: 0.7317
# Epoch: 37/150 Train Loss: 0.8804 Accuracy: 0.7158 Time: 3.92370  | Val Loss: 0.8352 Accuracy: 0.7343
# Epoch: 38/150 Train Loss: 0.9003 Accuracy: 0.7081 Time: 3.94238  | Val Loss: 0.9887 Accuracy: 0.6731
# Epoch: 39/150 Train Loss: 0.8676 Accuracy: 0.7242 Time: 3.89355  | Val Loss: 0.8609 Accuracy: 0.7236
# Epoch: 40/150 Train Loss: 0.8679 Accuracy: 0.7189 Time: 3.92881  | Val Loss: 0.8366 Accuracy: 0.7381
# Epoch: 41/150 Train Loss: 0.8653 Accuracy: 0.7206 Time: 3.86990  | Val Loss: 0.7873 Accuracy: 0.7549
# Epoch: 42/150 Train Loss: 0.8733 Accuracy: 0.7189 Time: 3.86599  | Val Loss: 0.8265 Accuracy: 0.7381
# Epoch: 43/150 Train Loss: 0.8616 Accuracy: 0.7247 Time: 3.79844  | Val Loss: 0.8642 Accuracy: 0.7279
# Epoch: 44/150 Train Loss: 0.8388 Accuracy: 0.7314 Time: 3.81605  | Val Loss: 0.7865 Accuracy: 0.7539
# Epoch: 45/150 Train Loss: 0.8565 Accuracy: 0.7218 Time: 3.86781  | Val Loss: 0.8309 Accuracy: 0.7355
# Epoch: 46/150 Train Loss: 0.7641 Accuracy: 0.7548 Time: 3.94809  | Val Loss: 0.7240 Accuracy: 0.7753
# Epoch: 47/150 Train Loss: 0.7273 Accuracy: 0.7701 Time: 3.86295  | Val Loss: 0.7602 Accuracy: 0.7552
# Epoch: 48/150 Train Loss: 0.7616 Accuracy: 0.7537 Time: 3.84569  | Val Loss: 0.7118 Accuracy: 0.7791
# Epoch: 49/150 Train Loss: 0.7386 Accuracy: 0.7615 Time: 3.87931  | Val Loss: 0.7538 Accuracy: 0.7625
# Epoch: 50/150 Train Loss: 0.7271 Accuracy: 0.7682 Time: 3.91548  | Val Loss: 0.7191 Accuracy: 0.7740
# Epoch: 51/150 Train Loss: 0.7106 Accuracy: 0.7709 Time: 3.94269  | Val Loss: 0.6976 Accuracy: 0.7804
# Epoch: 52/150 Train Loss: 0.7254 Accuracy: 0.7707 Time: 4.14524  | Val Loss: 0.7311 Accuracy: 0.7694
# Epoch: 53/150 Train Loss: 0.6984 Accuracy: 0.7749 Time: 3.97886  | Val Loss: 0.7292 Accuracy: 0.7712
# Epoch: 54/150 Train Loss: 0.7141 Accuracy: 0.7749 Time: 3.95778  | Val Loss: 0.6841 Accuracy: 0.7862
# Epoch: 55/150 Train Loss: 0.6862 Accuracy: 0.7794 Time: 3.95430  | Val Loss: 0.6939 Accuracy: 0.7903
# Epoch: 56/150 Train Loss: 0.7117 Accuracy: 0.7671 Time: 3.85016  | Val Loss: 0.7294 Accuracy: 0.7750
# Epoch: 57/150 Train Loss: 0.7132 Accuracy: 0.7706 Time: 4.09334  | Val Loss: 0.6798 Accuracy: 0.7906
# Epoch: 58/150 Train Loss: 0.7000 Accuracy: 0.7753 Time: 4.20958  | Val Loss: 0.6555 Accuracy: 0.7926
# Epoch: 59/150 Train Loss: 0.6974 Accuracy: 0.7765 Time: 3.97610  | Val Loss: 0.6855 Accuracy: 0.7832
# Epoch: 60/150 Train Loss: 0.6848 Accuracy: 0.7818 Time: 4.01110  | Val Loss: 0.6507 Accuracy: 0.7944
# Epoch: 61/150 Train Loss: 0.6279 Accuracy: 0.7985 Time: 3.92196  | Val Loss: 0.6504 Accuracy: 0.7931
# Epoch: 62/150 Train Loss: 0.6340 Accuracy: 0.7988 Time: 3.98551  | Val Loss: 0.6556 Accuracy: 0.7901
# Epoch: 63/150 Train Loss: 0.6324 Accuracy: 0.7983 Time: 4.23610  | Val Loss: 0.6474 Accuracy: 0.8010
# Epoch: 64/150 Train Loss: 0.6277 Accuracy: 0.7979 Time: 3.95909  | Val Loss: 0.6382 Accuracy: 0.8010
# Epoch: 65/150 Train Loss: 0.6137 Accuracy: 0.8060 Time: 4.04836  | Val Loss: 0.6697 Accuracy: 0.7934
# Epoch: 66/150 Train Loss: 0.6089 Accuracy: 0.8055 Time: 4.04514  | Val Loss: 0.6574 Accuracy: 0.7977
# Epoch: 67/150 Train Loss: 0.6190 Accuracy: 0.8015 Time: 4.04474  | Val Loss: 0.6451 Accuracy: 0.8028
# Epoch: 68/150 Train Loss: 0.6145 Accuracy: 0.8027 Time: 3.96352  | Val Loss: 0.6107 Accuracy: 0.8048
# Epoch: 69/150 Train Loss: 0.6046 Accuracy: 0.8078 Time: 4.10217  | Val Loss: 0.6375 Accuracy: 0.8005
# Epoch: 70/150 Train Loss: 0.5920 Accuracy: 0.8091 Time: 3.89863  | Val Loss: 0.6211 Accuracy: 0.8064
# Epoch: 71/150 Train Loss: 0.6028 Accuracy: 0.8075 Time: 3.96482  | Val Loss: 0.6051 Accuracy: 0.8107
# Epoch: 72/150 Train Loss: 0.5953 Accuracy: 0.8140 Time: 4.01596  | Val Loss: 0.6094 Accuracy: 0.8104
# Epoch: 73/150 Train Loss: 0.6001 Accuracy: 0.8049 Time: 3.87815  | Val Loss: 0.6413 Accuracy: 0.8020
# Epoch: 74/150 Train Loss: 0.5995 Accuracy: 0.8091 Time: 3.89092  | Val Loss: 0.6109 Accuracy: 0.8041
# Epoch: 75/150 Train Loss: 0.6018 Accuracy: 0.8067 Time: 4.00351  | Val Loss: 0.6784 Accuracy: 0.7870
# Epoch: 76/150 Train Loss: 0.5655 Accuracy: 0.8222 Time: 3.95198  | Val Loss: 0.5776 Accuracy: 0.8176
# Epoch: 77/150 Train Loss: 0.5527 Accuracy: 0.8227 Time: 4.22638  | Val Loss: 0.5858 Accuracy: 0.8135
# Epoch: 78/150 Train Loss: 0.5569 Accuracy: 0.8205 Time: 4.07455  | Val Loss: 0.6137 Accuracy: 0.8061
# Epoch: 79/150 Train Loss: 0.5432 Accuracy: 0.8262 Time: 3.90865  | Val Loss: 0.6105 Accuracy: 0.8015
# Epoch: 80/150 Train Loss: 0.5519 Accuracy: 0.8246 Time: 3.82772  | Val Loss: 0.5951 Accuracy: 0.8127
# Epoch: 81/150 Train Loss: 0.5398 Accuracy: 0.8269 Time: 3.89882  | Val Loss: 0.5842 Accuracy: 0.8158
# Epoch: 82/150 Train Loss: 0.5383 Accuracy: 0.8269 Time: 4.12716  | Val Loss: 0.5938 Accuracy: 0.8163
# Epoch: 83/150 Train Loss: 0.5363 Accuracy: 0.8255 Time: 3.96190  | Val Loss: 0.5903 Accuracy: 0.8104
# Epoch: 84/150 Train Loss: 0.5398 Accuracy: 0.8318 Time: 3.83199  | Val Loss: 0.6366 Accuracy: 0.8076
# Epoch: 85/150 Train Loss: 0.5369 Accuracy: 0.8308 Time: 3.83729  | Val Loss: 0.6213 Accuracy: 0.8079
# Epoch: 86/150 Train Loss: 0.5367 Accuracy: 0.8283 Time: 3.90082  | Val Loss: 0.6216 Accuracy: 0.8112
# Epoch: 87/150 Train Loss: 0.5357 Accuracy: 0.8329 Time: 3.88851  | Val Loss: 0.6020 Accuracy: 0.8132
# Epoch: 88/150 Train Loss: 0.5302 Accuracy: 0.8284 Time: 3.85470  | Val Loss: 0.5871 Accuracy: 0.8130
# Epoch: 89/150 Train Loss: 0.5390 Accuracy: 0.8236 Time: 3.90562  | Val Loss: 0.5809 Accuracy: 0.8153
# Epoch: 90/150 Train Loss: 0.5213 Accuracy: 0.8338 Time: 3.89959  | Val Loss: 0.6066 Accuracy: 0.8163
# Epoch: 91/150 Train Loss: 0.5097 Accuracy: 0.8389 Time: 3.86141  | Val Loss: 0.5644 Accuracy: 0.8199
# Epoch: 92/150 Train Loss: 0.5024 Accuracy: 0.8415 Time: 3.86918  | Val Loss: 0.5809 Accuracy: 0.8186
# Epoch: 93/150 Train Loss: 0.4889 Accuracy: 0.8441 Time: 3.83476  | Val Loss: 0.5783 Accuracy: 0.8222
# Epoch: 94/150 Train Loss: 0.4938 Accuracy: 0.8433 Time: 3.86662  | Val Loss: 0.5826 Accuracy: 0.8206
# Epoch: 95/150 Train Loss: 0.4977 Accuracy: 0.8428 Time: 3.94797  | Val Loss: 0.5581 Accuracy: 0.8227
# Epoch: 96/150 Train Loss: 0.5046 Accuracy: 0.8380 Time: 3.86144  | Val Loss: 0.5571 Accuracy: 0.8250
# Epoch: 97/150 Train Loss: 0.4819 Accuracy: 0.8459 Time: 3.92383  | Val Loss: 0.6006 Accuracy: 0.8138
# Epoch: 98/150 Train Loss: 0.4994 Accuracy: 0.8408 Time: 3.81360  | Val Loss: 0.6029 Accuracy: 0.8145
# Epoch: 99/150 Train Loss: 0.4947 Accuracy: 0.8377 Time: 3.82388  | Val Loss: 0.5745 Accuracy: 0.8227
# Epoch: 100/150 Train Loss: 0.4879 Accuracy: 0.8437 Time: 3.94847  | Val Loss: 0.5902 Accuracy: 0.8161
# Epoch: 101/150 Train Loss: 0.4993 Accuracy: 0.8413 Time: 3.91704  | Val Loss: 0.5859 Accuracy: 0.8181
# Epoch: 102/150 Train Loss: 0.4905 Accuracy: 0.8432 Time: 3.96163  | Val Loss: 0.5749 Accuracy: 0.8211
# Epoch: 103/150 Train Loss: 0.4736 Accuracy: 0.8505 Time: 3.97962  | Val Loss: 0.6061 Accuracy: 0.8183
# Epoch: 104/150 Train Loss: 0.4840 Accuracy: 0.8472 Time: 3.91353  | Val Loss: 0.5602 Accuracy: 0.8252
# Epoch: 105/150 Train Loss: 0.4875 Accuracy: 0.8429 Time: 3.96118  | Val Loss: 0.5684 Accuracy: 0.8222
# Epoch: 106/150 Train Loss: 0.4672 Accuracy: 0.8545 Time: 3.99264  | Val Loss: 0.5651 Accuracy: 0.8285
# Epoch: 107/150 Train Loss: 0.4672 Accuracy: 0.8519 Time: 3.89472  | Val Loss: 0.5648 Accuracy: 0.8245
# Epoch: 108/150 Train Loss: 0.4842 Accuracy: 0.8487 Time: 3.85554  | Val Loss: 0.5530 Accuracy: 0.8280
# Epoch: 109/150 Train Loss: 0.4634 Accuracy: 0.8535 Time: 3.85846  | Val Loss: 0.5514 Accuracy: 0.8268
# Epoch: 110/150 Train Loss: 0.4709 Accuracy: 0.8471 Time: 3.87297  | Val Loss: 0.5684 Accuracy: 0.8234
# Epoch: 111/150 Train Loss: 0.4670 Accuracy: 0.8541 Time: 3.96136  | Val Loss: 0.5511 Accuracy: 0.8296
# Epoch: 112/150 Train Loss: 0.4603 Accuracy: 0.8533 Time: 3.89940  | Val Loss: 0.5720 Accuracy: 0.8229
# Epoch: 113/150 Train Loss: 0.4699 Accuracy: 0.8524 Time: 3.94468  | Val Loss: 0.5614 Accuracy: 0.8278
# Epoch: 114/150 Train Loss: 0.4585 Accuracy: 0.8566 Time: 4.03877  | Val Loss: 0.5470 Accuracy: 0.8260
# Epoch: 115/150 Train Loss: 0.4534 Accuracy: 0.8542 Time: 4.09733  | Val Loss: 0.5553 Accuracy: 0.8250
# Epoch: 116/150 Train Loss: 0.4688 Accuracy: 0.8485 Time: 4.93044  | Val Loss: 0.5508 Accuracy: 0.8288
# Epoch: 117/150 Train Loss: 0.4638 Accuracy: 0.8498 Time: 3.96214  | Val Loss: 0.5705 Accuracy: 0.8211
# Epoch: 118/150 Train Loss: 0.4550 Accuracy: 0.8558 Time: 5.11385  | Val Loss: 0.5501 Accuracy: 0.8278
# Epoch: 119/150 Train Loss: 0.4506 Accuracy: 0.8612 Time: 4.06763  | Val Loss: 0.5660 Accuracy: 0.8252
# Epoch: 120/150 Train Loss: 0.4599 Accuracy: 0.8536 Time: 3.96386  | Val Loss: 0.5586 Accuracy: 0.8270
# Epoch: 121/150 Train Loss: 0.4589 Accuracy: 0.8560 Time: 3.94929  | Val Loss: 0.5425 Accuracy: 0.8324
# Epoch: 122/150 Train Loss: 0.4568 Accuracy: 0.8586 Time: 3.95027  | Val Loss: 0.5444 Accuracy: 0.8334
# Epoch: 123/150 Train Loss: 0.4365 Accuracy: 0.8606 Time: 3.83591  | Val Loss: 0.5608 Accuracy: 0.8288
# Epoch: 124/150 Train Loss: 0.4576 Accuracy: 0.8545 Time: 3.89617  | Val Loss: 0.5491 Accuracy: 0.8303
# Epoch: 125/150 Train Loss: 0.4470 Accuracy: 0.8563 Time: 3.87420  | Val Loss: 0.5466 Accuracy: 0.8331
# Epoch: 126/150 Train Loss: 0.4493 Accuracy: 0.8595 Time: 3.90164  | Val Loss: 0.5574 Accuracy: 0.8288
# Epoch: 127/150 Train Loss: 0.4513 Accuracy: 0.8586 Time: 4.32783  | Val Loss: 0.5429 Accuracy: 0.8331
# Epoch: 128/150 Train Loss: 0.4493 Accuracy: 0.8562 Time: 3.87038  | Val Loss: 0.5479 Accuracy: 0.8293
# Epoch: 129/150 Train Loss: 0.4466 Accuracy: 0.8579 Time: 3.90311  | Val Loss: 0.5552 Accuracy: 0.8318
# Epoch: 130/150 Train Loss: 0.4477 Accuracy: 0.8548 Time: 3.80644  | Val Loss: 0.5642 Accuracy: 0.8262
# Epoch: 131/150 Train Loss: 0.4551 Accuracy: 0.8547 Time: 3.88157  | Val Loss: 0.5397 Accuracy: 0.8341
# Epoch: 132/150 Train Loss: 0.4366 Accuracy: 0.8610 Time: 3.89950  | Val Loss: 0.5584 Accuracy: 0.8293
# Epoch: 133/150 Train Loss: 0.4485 Accuracy: 0.8573 Time: 3.87364  | Val Loss: 0.5414 Accuracy: 0.8339
# Epoch: 134/150 Train Loss: 0.4505 Accuracy: 0.8590 Time: 3.85262  | Val Loss: 0.5558 Accuracy: 0.8288
# Epoch: 135/150 Train Loss: 0.4472 Accuracy: 0.8567 Time: 3.87204  | Val Loss: 0.5620 Accuracy: 0.8290
# Epoch: 136/150 Train Loss: 0.4441 Accuracy: 0.8601 Time: 3.91046  | Val Loss: 0.5438 Accuracy: 0.8311
# Epoch: 137/150 Train Loss: 0.4475 Accuracy: 0.8558 Time: 3.89298  | Val Loss: 0.5490 Accuracy: 0.8326
# Epoch: 138/150 Train Loss: 0.4450 Accuracy: 0.8575 Time: 3.81270  | Val Loss: 0.5465 Accuracy: 0.8316
# Epoch: 139/150 Train Loss: 0.4385 Accuracy: 0.8623 Time: 3.94766  | Val Loss: 0.5454 Accuracy: 0.8324
# Epoch: 140/150 Train Loss: 0.4386 Accuracy: 0.8587 Time: 3.88786  | Val Loss: 0.5479 Accuracy: 0.8311
# Epoch: 141/150 Train Loss: 0.4327 Accuracy: 0.8628 Time: 3.89513  | Val Loss: 0.5448 Accuracy: 0.8339
# Epoch: 142/150 Train Loss: 0.4407 Accuracy: 0.8599 Time: 3.86936  | Val Loss: 0.5453 Accuracy: 0.8301
# Epoch: 143/150 Train Loss: 0.4403 Accuracy: 0.8605 Time: 3.85975  | Val Loss: 0.5512 Accuracy: 0.8318
# Epoch: 144/150 Train Loss: 0.4389 Accuracy: 0.8623 Time: 3.84483  | Val Loss: 0.5479 Accuracy: 0.8331
# Epoch: 145/150 Train Loss: 0.4370 Accuracy: 0.8615 Time: 3.94739  | Val Loss: 0.5560 Accuracy: 0.8331
# Epoch: 146/150 Train Loss: 0.4447 Accuracy: 0.8580 Time: 3.82390  | Val Loss: 0.5512 Accuracy: 0.8301
# Early stop at epoch 146!

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.figure(figsize=(12,12))
fields = train_statistics_with_norm.keys()
for i, field in enumerate(fields):
    plt.subplot(2, 2, i+1)
    plt.plot(train_statistics_with_norm[field], label="With Batch Norm", linestyle="-")
    plt.plot(train_statistics_without_norm[field], label="Without Batch Norm", linestyle="--")
    plt.legend()
    plt.title(field)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from collections import defaultdict
from collections import namedtuple
from hdd.train.classification_utils import eval_image_classifier

eval_result = eval_image_classifier(net, val_dataloader.dataset, DEVICE)

# %%
images_per_class = 5
per_class_image_count = defaultdict(int)
num_classes = 10
val_dataset = val_dataloader.dataset
fig, axes = plt.subplots(nrows=images_per_class, ncols=num_classes, figsize=(18, 12))
fig.suptitle("Wrongly Classified Examples", fontsize=14)
for sample in eval_result:
    idx = sample.idx
    predicted_label = sample.predicted_label
    gt_label = sample.gt_label
    if gt_label == predicted_label:
        continue
    i = per_class_image_count[gt_label]
    if i >= images_per_class:
        continue
    per_class_image_count[gt_label] += 1
    plt_idx = i * num_classes + gt_label + 1
    plt.subplot(images_per_class, num_classes, plt_idx)
    image = val_dataset._loaded_images[idx]
    plt.imshow(image)
    plt.axis("off")
    predicted_class_name = val_dataset.classes[predicted_label][0]
    plt.title(predicted_class_name)
gt_names = [c[0] for c in val_dataset.classes]
plt.show()

# %%
import numpy as np
from sklearn.metrics import confusion_matrix

all_gts = []
all_predictions = []
for item in eval_result:
    all_gts.append(item.gt_label)
    all_predictions.append(item.predicted_label)
cm = confusion_matrix(all_gts, all_predictions)

class_names = [
    "tench",
    "English springer",
    "cassette player",
    "chain saw",
    "church",
    "French horn",
    "garbage truck",
    "gas pump",
    "golf ball",
    "parachute",
]

fig, ax = plt.subplots(figsize=(10, 8))
im = ax.imshow(cm, interpolation="nearest", cmap=plt.cm.Blues)
ax.figure.colorbar(im, ax=ax)

ax.set(
    xticks=np.arange(cm.shape[1]),
    yticks=np.arange(cm.shape[0]),
    xticklabels=class_names,
    yticklabels=class_names,
    title="Confusion Matrix",
    ylabel="True label",
    xlabel="Predicted label",
)

plt.setp(ax.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")

thresh = cm.max() / 2.0
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax.text(
            j,
            i,
            format(cm[i, j], "d"),
            ha="center",
            va="center",
            color="white" if cm[i, j] > thresh else "black",
        )

fig.tight_layout()
plt.show()

# %%
# 可视化网络的第一个卷积层的权重
from hdd.visualization.vis_utils import visualize_grid

W = net.features[0].conv2d.weight
W = W.detach().to("cpu").numpy()
W = W.transpose(0, 2, 3, 1)
plt.figure(figsize=(3, 3))
plt.imshow(visualize_grid(W, padding=1).astype("uint8"))
plt.gca().axis("off")
plt.show()
