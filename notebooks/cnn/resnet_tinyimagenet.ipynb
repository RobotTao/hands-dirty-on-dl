# %% [markdown]
# ## Resnet on Tiny ImageNet
#
# 在[resnet.ipynb](./resnet.ipynb)中我们测试了Resnet在Imagenette上的分类任务, Imagenette是只包含10类的ImageNet的子集,这里我们在TinyImagenet上测试对比不同的Resnet网络效果.
#
# Tiny ImageNet 包含 100000 张图片，涵盖了200个类别（每个类别有500张图片），图片大小为64×64，并且为彩色图片。每个类别有500张训练图片，50张验证图片和50张测试图片。
#
# 随机挑选的15个类别:
#
# ![alt text](resources/tinyimagenet.png "Title")

# %%
# 自动重新加载外部module，使得修改代码之后无需重新import
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

from hdd.device.utils import get_device

import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms

# 设置训练数据的路径
DATA_ROOT = "~/workspace/hands-dirty-on-dl/dataset"
# 设置TensorBoard的路径
TENSORBOARD_ROOT = "~/workspace/hands-dirty-on-dl/dataset"
# 设置预训练模型参数路径
TORCH_HUB_PATH = "~/workspace/hands-dirty-on-dl/pretrained_models"
torch.hub.set_dir(TORCH_HUB_PATH)
# 挑选最合适的训练设备
DEVICE = get_device(["cuda", "cpu"])
print("Use device: ", DEVICE)
# Out:
# Use device:  cuda

# %%
from hdd.dataset.tiny_imagenet import TinyImagenet
import torchvision.transforms.v2

# 提前计算好了均值和方差
TRAIN_MEAN = [0.4802, 0.4481, 0.3975]
TRAIN_STD = [0.2302, 0.2265, 0.2262]


train_dataset_transforms = transforms.Compose(
    [
        torchvision.transforms.v2.RandomResize(66, 72),
        transforms.RandomRotation(3),
        transforms.RandomCrop(64),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize(mean=TRAIN_MEAN, std=TRAIN_STD),
    ]
)
train_dataset = TinyImagenet(
    root=DATA_ROOT, split="train", download=True, transform=train_dataset_transforms
)
val_dataset = TinyImagenet(
    root=DATA_ROOT,
    split="val",
    download=True,
    transform=transforms.Compose(
        [transforms.ToTensor(), transforms.Normalize(TRAIN_MEAN, TRAIN_STD)]
    ),
)
print("Basic Info of train dataaset: \n", train_dataset)
print("Basic Info of test dataset: \n", val_dataset)
# Out:
# Basic Info of train dataaset:
#  Dataset TinyImagenet
#     Number of datapoints: 100000
#     Root location: /home/tf/workspace/hands-dirty-on-dl/dataset
#     StandardTransform
# Transform: Compose(
#                RandomResize(min_size=66, max_size=72, interpolation=InterpolationMode.BILINEAR, antialias=True)
#                RandomRotation(degrees=[-3.0, 3.0], interpolation=nearest, expand=False, fill=0)
#                RandomCrop(size=(64, 64), padding=None)
#                RandomHorizontalFlip(p=0.5)
#                ToTensor()
#                Normalize(mean=[0.4802, 0.4481, 0.3975], std=[0.2302, 0.2265, 0.2262])
#            )
# Basic Info of test dataset:
#  Dataset TinyImagenet
#     Number of datapoints: 10000
#     Root location: /home/tf/workspace/hands-dirty-on-dl/dataset
#     StandardTransform
# Transform: Compose(
#                ToTensor()
#                Normalize(mean=[0.4802, 0.4481, 0.3975], std=[0.2302, 0.2265, 0.2262])
#            )

# %%
BATCH_SIZE = 64
train_dataloader = torch.utils.data.DataLoader(
    train_dataset,
    batch_size=BATCH_SIZE,
    shuffle=True,
)
val_dataloader = torch.utils.data.DataLoader(
    val_dataset,
    batch_size=BATCH_SIZE,
    shuffle=False,
)

# %% [markdown]
# ## 测试比较不同的Resnet架构

# %%
from spacy import training
from hdd.models.cnn.resnet import ResnetSmall, resnet18_config
from hdd.train.early_stopping import EarlyStoppingInMem
from hdd.train.classification_utils import (
    naive_train_classification_model,
    eval_image_classifier,
)
from hdd.models.nn_utils import count_trainable_parameter


def train_net(
    resnet_config,
    train_dataloader,
    val_dataloader,
    dropout,
    lr,
    weight_decay,
    step_size=30,
    gamma=0.1,
    patience=40,
    max_epochs=120,
) -> tuple[ResnetSmall, dict[str, list[float]]]:
    net = ResnetSmall(resnet_config, num_classes=200, dropout=dropout).to(DEVICE)
    criteria = nn.CrossEntropyLoss()
    # SGD的收敛速度远不如Adam好
    # optimizer = torch.optim.SGD(
    #     net.parameters(), lr=lr, momentum=0.9, weight_decay=weight_decay
    # )
    optimizer = optim.AdamW(
        net.parameters(), lr=lr, eps=1e-6, weight_decay=weight_decay
    )
    scheduler = torch.optim.lr_scheduler.StepLR(
        optimizer, step_size=step_size, gamma=gamma, last_epoch=-1
    )
    early_stopper = EarlyStoppingInMem(patience=patience, verbose=False)
    training_stats = naive_train_classification_model(
        net,
        criteria,
        max_epochs,
        train_dataloader,
        val_dataloader,
        DEVICE,
        optimizer,
        scheduler,
        early_stopper,
        verbose=True,
    )
    return net, training_stats


net, resnet18_stats = train_net(
    resnet18_config,
    train_dataloader,
    val_dataloader,
    dropout=0.5,
    lr=0.005,
    weight_decay=1e-2,
)

eval_result = eval_image_classifier(net, val_dataloader.dataset, DEVICE)
ss = [result.gt_label == result.predicted_label for result in eval_result]
print(f"#Parameter: {count_trainable_parameter(net)} Accuracy: {sum(ss) / len(ss)}")
# Out:
# Epoch: 1/120 Train Loss: 4.7006 Accuracy: 0.0528 Time: 63.13437  | Val Loss: 4.3960 Accuracy: 0.0854
# Epoch: 2/120 Train Loss: 3.9700 Accuracy: 0.1361 Time: 62.87105  | Val Loss: 3.6732 Accuracy: 0.1883
# Epoch: 3/120 Train Loss: 3.5430 Accuracy: 0.2017 Time: 62.97417  | Val Loss: 3.5985 Accuracy: 0.1993
# Epoch: 4/120 Train Loss: 3.2475 Accuracy: 0.2553 Time: 62.57284  | Val Loss: 3.2399 Accuracy: 0.2616
# Epoch: 5/120 Train Loss: 3.0202 Accuracy: 0.2968 Time: 62.38601  | Val Loss: 3.4862 Accuracy: 0.2313
# Epoch: 6/120 Train Loss: 2.8270 Accuracy: 0.3346 Time: 60.49896  | Val Loss: 3.1019 Accuracy: 0.2943
# Epoch: 7/120 Train Loss: 2.6774 Accuracy: 0.3674 Time: 60.54692  | Val Loss: 3.2807 Accuracy: 0.2776
# Epoch: 8/120 Train Loss: 2.5473 Accuracy: 0.3917 Time: 60.56805  | Val Loss: 2.7279 Accuracy: 0.3597
# Epoch: 9/120 Train Loss: 2.4343 Accuracy: 0.4171 Time: 60.57106  | Val Loss: 3.1570 Accuracy: 0.3223
# Epoch: 10/120 Train Loss: 2.3302 Accuracy: 0.4373 Time: 60.54537  | Val Loss: 2.7059 Accuracy: 0.3860
# Epoch: 11/120 Train Loss: 2.2425 Accuracy: 0.4545 Time: 60.53535  | Val Loss: 3.2167 Accuracy: 0.3206
# Epoch: 12/120 Train Loss: 2.1700 Accuracy: 0.4687 Time: 60.54756  | Val Loss: 2.9942 Accuracy: 0.3497
# Epoch: 13/120 Train Loss: 2.1008 Accuracy: 0.4833 Time: 60.50998  | Val Loss: 2.6914 Accuracy: 0.3933
# Epoch: 14/120 Train Loss: 2.0377 Accuracy: 0.5008 Time: 60.51119  | Val Loss: 2.4296 Accuracy: 0.4412
# Epoch: 15/120 Train Loss: 1.9820 Accuracy: 0.5093 Time: 60.51395  | Val Loss: 2.7315 Accuracy: 0.3824
# Epoch: 16/120 Train Loss: 1.9371 Accuracy: 0.5188 Time: 60.55694  | Val Loss: 2.6723 Accuracy: 0.4092
# Epoch: 17/120 Train Loss: 1.9003 Accuracy: 0.5282 Time: 60.54720  | Val Loss: 2.3815 Accuracy: 0.4535
# Epoch: 18/120 Train Loss: 1.8458 Accuracy: 0.5396 Time: 60.57605  | Val Loss: 2.4067 Accuracy: 0.4477
# Epoch: 19/120 Train Loss: 1.8103 Accuracy: 0.5461 Time: 60.55547  | Val Loss: 2.5678 Accuracy: 0.4266
# Epoch: 20/120 Train Loss: 1.7785 Accuracy: 0.5522 Time: 60.55974  | Val Loss: 3.0416 Accuracy: 0.3776
# Epoch: 21/120 Train Loss: 1.7427 Accuracy: 0.5630 Time: 60.53491  | Val Loss: 2.8259 Accuracy: 0.3964
# Epoch: 22/120 Train Loss: 1.7157 Accuracy: 0.5677 Time: 60.51807  | Val Loss: 2.4694 Accuracy: 0.4409
# Epoch: 23/120 Train Loss: 1.6880 Accuracy: 0.5739 Time: 60.53853  | Val Loss: 2.3620 Accuracy: 0.4668
# Epoch: 24/120 Train Loss: 1.6613 Accuracy: 0.5788 Time: 60.52121  | Val Loss: 2.7066 Accuracy: 0.4181
# Epoch: 25/120 Train Loss: 1.6304 Accuracy: 0.5867 Time: 60.53300  | Val Loss: 2.7331 Accuracy: 0.4195
# Epoch: 26/120 Train Loss: 1.6099 Accuracy: 0.5916 Time: 60.54484  | Val Loss: 2.7196 Accuracy: 0.4167
# Epoch: 27/120 Train Loss: 1.5937 Accuracy: 0.5962 Time: 60.52477  | Val Loss: 2.5223 Accuracy: 0.4422
# Epoch: 28/120 Train Loss: 1.5777 Accuracy: 0.5999 Time: 60.53430  | Val Loss: 2.4914 Accuracy: 0.4408
# Epoch: 29/120 Train Loss: 1.5581 Accuracy: 0.6027 Time: 60.53242  | Val Loss: 2.8572 Accuracy: 0.3992
# Epoch: 30/120 Train Loss: 1.5421 Accuracy: 0.6070 Time: 60.55139  | Val Loss: 2.6272 Accuracy: 0.4372
# Epoch: 31/120 Train Loss: 1.0945 Accuracy: 0.7120 Time: 60.53370  | Val Loss: 2.1642 Accuracy: 0.5202
# Epoch: 32/120 Train Loss: 0.9517 Accuracy: 0.7434 Time: 60.56406  | Val Loss: 2.1823 Accuracy: 0.5285
# Epoch: 33/120 Train Loss: 0.8824 Accuracy: 0.7611 Time: 60.50182  | Val Loss: 2.1805 Accuracy: 0.5322
# Epoch: 34/120 Train Loss: 0.8292 Accuracy: 0.7744 Time: 60.52330  | Val Loss: 2.2249 Accuracy: 0.5315
# Epoch: 35/120 Train Loss: 0.7893 Accuracy: 0.7837 Time: 60.57139  | Val Loss: 2.1980 Accuracy: 0.5383
# Epoch: 36/120 Train Loss: 0.7494 Accuracy: 0.7935 Time: 60.55819  | Val Loss: 2.4755 Accuracy: 0.5169
# Epoch: 37/120 Train Loss: 0.7189 Accuracy: 0.8000 Time: 60.53611  | Val Loss: 2.2914 Accuracy: 0.5337
# Epoch: 38/120 Train Loss: 0.6870 Accuracy: 0.8084 Time: 60.52367  | Val Loss: 2.4141 Accuracy: 0.5221
# Epoch: 39/120 Train Loss: 0.6611 Accuracy: 0.8136 Time: 60.53071  | Val Loss: 2.4184 Accuracy: 0.5187
# Epoch: 40/120 Train Loss: 0.6308 Accuracy: 0.8227 Time: 60.52535  | Val Loss: 2.4318 Accuracy: 0.5268
# Epoch: 41/120 Train Loss: 0.6083 Accuracy: 0.8265 Time: 60.56821  | Val Loss: 2.4559 Accuracy: 0.5262
# Epoch: 42/120 Train Loss: 0.5851 Accuracy: 0.8337 Time: 60.51830  | Val Loss: 2.4523 Accuracy: 0.5253
# Epoch: 43/120 Train Loss: 0.5668 Accuracy: 0.8371 Time: 60.53030  | Val Loss: 2.5544 Accuracy: 0.5173
# Epoch: 44/120 Train Loss: 0.5467 Accuracy: 0.8430 Time: 60.55491  | Val Loss: 2.4797 Accuracy: 0.5273
# Epoch: 45/120 Train Loss: 0.5272 Accuracy: 0.8486 Time: 60.56099  | Val Loss: 2.5267 Accuracy: 0.5262
# Epoch: 46/120 Train Loss: 0.5126 Accuracy: 0.8528 Time: 60.55615  | Val Loss: 2.6373 Accuracy: 0.5178
# Epoch: 47/120 Train Loss: 0.4929 Accuracy: 0.8566 Time: 60.53241  | Val Loss: 2.5858 Accuracy: 0.5239
# Epoch: 48/120 Train Loss: 0.4743 Accuracy: 0.8616 Time: 60.60450  | Val Loss: 2.6683 Accuracy: 0.5208
# Epoch: 49/120 Train Loss: 0.4596 Accuracy: 0.8656 Time: 60.53534  | Val Loss: 2.6773 Accuracy: 0.5215
# Epoch: 50/120 Train Loss: 0.4482 Accuracy: 0.8686 Time: 60.53744  | Val Loss: 2.6943 Accuracy: 0.5252
# Epoch: 51/120 Train Loss: 0.4375 Accuracy: 0.8705 Time: 60.54755  | Val Loss: 2.6497 Accuracy: 0.5249
# Epoch: 52/120 Train Loss: 0.4122 Accuracy: 0.8783 Time: 60.53888  | Val Loss: 2.7222 Accuracy: 0.5230
# Epoch: 53/120 Train Loss: 0.4043 Accuracy: 0.8794 Time: 60.56637  | Val Loss: 2.7965 Accuracy: 0.5193
# Epoch: 54/120 Train Loss: 0.3949 Accuracy: 0.8831 Time: 60.52882  | Val Loss: 2.6852 Accuracy: 0.5287
# Epoch: 55/120 Train Loss: 0.3796 Accuracy: 0.8872 Time: 60.55562  | Val Loss: 2.8032 Accuracy: 0.5236
# Epoch: 56/120 Train Loss: 0.3723 Accuracy: 0.8890 Time: 60.55389  | Val Loss: 2.9663 Accuracy: 0.5087
# Epoch: 57/120 Train Loss: 0.3657 Accuracy: 0.8900 Time: 60.55437  | Val Loss: 2.8974 Accuracy: 0.5171
# Epoch: 58/120 Train Loss: 0.3469 Accuracy: 0.8955 Time: 60.54337  | Val Loss: 2.9791 Accuracy: 0.5101
# Epoch: 59/120 Train Loss: 0.3419 Accuracy: 0.8974 Time: 60.53569  | Val Loss: 2.9935 Accuracy: 0.5141
# Epoch: 60/120 Train Loss: 0.3330 Accuracy: 0.9001 Time: 60.55239  | Val Loss: 2.9094 Accuracy: 0.5221
# Epoch: 61/120 Train Loss: 0.2827 Accuracy: 0.9162 Time: 60.58447  | Val Loss: 3.0344 Accuracy: 0.5110
# Epoch: 62/120 Train Loss: 0.2659 Accuracy: 0.9216 Time: 60.62432  | Val Loss: 2.9434 Accuracy: 0.5199
# Epoch: 63/120 Train Loss: 0.2619 Accuracy: 0.9209 Time: 60.54892  | Val Loss: 2.9537 Accuracy: 0.5212
# Epoch: 64/120 Train Loss: 0.2539 Accuracy: 0.9240 Time: 60.59117  | Val Loss: 3.0109 Accuracy: 0.5155
# Epoch: 65/120 Train Loss: 0.2487 Accuracy: 0.9253 Time: 60.54138  | Val Loss: 2.9307 Accuracy: 0.5243
# Epoch: 66/120 Train Loss: 0.2493 Accuracy: 0.9252 Time: 60.56632  | Val Loss: 2.9998 Accuracy: 0.5213
# Epoch: 67/120 Train Loss: 0.2442 Accuracy: 0.9270 Time: 60.54717  | Val Loss: 2.9661 Accuracy: 0.5244
# Epoch: 68/120 Train Loss: 0.2403 Accuracy: 0.9280 Time: 60.49776  | Val Loss: 2.9721 Accuracy: 0.5228
# Epoch: 69/120 Train Loss: 0.2409 Accuracy: 0.9271 Time: 60.56912  | Val Loss: 3.0589 Accuracy: 0.5193
# Epoch: 70/120 Train Loss: 0.2332 Accuracy: 0.9298 Time: 60.56042  | Val Loss: 3.0666 Accuracy: 0.5178
# Epoch: 71/120 Train Loss: 0.2323 Accuracy: 0.9301 Time: 60.58005  | Val Loss: 3.0353 Accuracy: 0.5218
# Early stop at epoch 71!
# #Parameter: 11271432 Accuracy: 0.5201

# %%
from hdd.models.cnn.resnet import resnet34_config

net, resnet34_stats = train_net(
    resnet34_config,
    train_dataloader,
    val_dataloader,
    dropout=0.5,
    lr=0.05,
    weight_decay=1e-2,
)

eval_result = eval_image_classifier(net, val_dataloader.dataset, DEVICE)
ss = [result.gt_label == result.predicted_label for result in eval_result]
print(f"#Parameter: {count_trainable_parameter(net)} Accuracy: {sum(ss) / len(ss)}")
# Out:
# Epoch: 1/120 Train Loss: 5.2847 Accuracy: 0.0075 Time: 102.45276  | Val Loss: 5.3287 Accuracy: 0.0053
# Epoch: 2/120 Train Loss: 5.2336 Accuracy: 0.0088 Time: 102.45402  | Val Loss: 5.2376 Accuracy: 0.0111
# Epoch: 3/120 Train Loss: 5.2131 Accuracy: 0.0094 Time: 102.43996  | Val Loss: 5.1594 Accuracy: 0.0126
# Epoch: 4/120 Train Loss: 5.1762 Accuracy: 0.0105 Time: 102.43808  | Val Loss: 5.1073 Accuracy: 0.0130
# Epoch: 5/120 Train Loss: 5.1691 Accuracy: 0.0113 Time: 102.41869  | Val Loss: 5.1693 Accuracy: 0.0105
# Epoch: 6/120 Train Loss: 5.1633 Accuracy: 0.0114 Time: 102.38357  | Val Loss: 5.6657 Accuracy: 0.0097
# Epoch: 7/120 Train Loss: 5.1570 Accuracy: 0.0117 Time: 102.37989  | Val Loss: 6.8334 Accuracy: 0.0103
# Epoch: 8/120 Train Loss: 5.1298 Accuracy: 0.0119 Time: 102.36425  | Val Loss: 5.0727 Accuracy: 0.0151
# Epoch: 9/120 Train Loss: 5.0950 Accuracy: 0.0134 Time: 102.37211  | Val Loss: 5.3892 Accuracy: 0.0111
# Epoch: 10/120 Train Loss: 5.0718 Accuracy: 0.0137 Time: 102.35102  | Val Loss: 5.9277 Accuracy: 0.0101
# Epoch: 11/120 Train Loss: 5.0581 Accuracy: 0.0145 Time: 102.35139  | Val Loss: 8.4197 Accuracy: 0.0063
# Epoch: 12/120 Train Loss: 5.0434 Accuracy: 0.0149 Time: 102.35707  | Val Loss: 5.1501 Accuracy: 0.0200
# Epoch: 13/120 Train Loss: 5.0306 Accuracy: 0.0152 Time: 102.37511  | Val Loss: 5.8927 Accuracy: 0.0129
# Epoch: 14/120 Train Loss: 5.0258 Accuracy: 0.0153 Time: 102.36289  | Val Loss: 5.0328 Accuracy: 0.0174
# Epoch: 15/120 Train Loss: 5.0214 Accuracy: 0.0157 Time: 102.42653  | Val Loss: 4.9162 Accuracy: 0.0193
# Epoch: 16/120 Train Loss: 5.0190 Accuracy: 0.0158 Time: 102.41412  | Val Loss: 5.0954 Accuracy: 0.0140
# Epoch: 17/120 Train Loss: 5.0157 Accuracy: 0.0165 Time: 102.38404  | Val Loss: 4.9385 Accuracy: 0.0159
# Epoch: 18/120 Train Loss: 5.0029 Accuracy: 0.0161 Time: 102.40097  | Val Loss: 5.6540 Accuracy: 0.0141
# Epoch: 19/120 Train Loss: 4.9970 Accuracy: 0.0167 Time: 102.39416  | Val Loss: 5.2421 Accuracy: 0.0177
# Epoch: 20/120 Train Loss: 4.9944 Accuracy: 0.0165 Time: 102.37235  | Val Loss: 5.1382 Accuracy: 0.0148
# Epoch: 21/120 Train Loss: 4.9929 Accuracy: 0.0163 Time: 102.37928  | Val Loss: 4.9953 Accuracy: 0.0176
# Epoch: 22/120 Train Loss: 4.9943 Accuracy: 0.0157 Time: 102.39459  | Val Loss: 4.8458 Accuracy: 0.0216
# Epoch: 23/120 Train Loss: 4.9922 Accuracy: 0.0162 Time: 102.40203  | Val Loss: 5.8060 Accuracy: 0.0127
# Epoch: 24/120 Train Loss: 4.9924 Accuracy: 0.0159 Time: 102.37043  | Val Loss: 5.0563 Accuracy: 0.0174
# Epoch: 25/120 Train Loss: 4.9939 Accuracy: 0.0158 Time: 102.38942  | Val Loss: 4.9423 Accuracy: 0.0166
# Epoch: 26/120 Train Loss: 4.9875 Accuracy: 0.0168 Time: 102.42750  | Val Loss: 5.6178 Accuracy: 0.0160
# Epoch: 27/120 Train Loss: 4.9937 Accuracy: 0.0166 Time: 102.37583  | Val Loss: 5.0607 Accuracy: 0.0159
# Epoch: 28/120 Train Loss: 4.9964 Accuracy: 0.0173 Time: 102.37028  | Val Loss: 5.9377 Accuracy: 0.0078
# Epoch: 29/120 Train Loss: 4.9933 Accuracy: 0.0173 Time: 102.39007  | Val Loss: 4.9236 Accuracy: 0.0214
# Epoch: 30/120 Train Loss: 4.9909 Accuracy: 0.0167 Time: 102.38897  | Val Loss: 6.6904 Accuracy: 0.0061
# Epoch: 31/120 Train Loss: 4.8909 Accuracy: 0.0212 Time: 102.36877  | Val Loss: 4.7448 Accuracy: 0.0288
# Epoch: 32/120 Train Loss: 4.8626 Accuracy: 0.0223 Time: 102.36657  | Val Loss: 4.9043 Accuracy: 0.0261
# Epoch: 33/120 Train Loss: 4.8481 Accuracy: 0.0224 Time: 102.38543  | Val Loss: 4.8402 Accuracy: 0.0282
# Epoch: 34/120 Train Loss: 4.8401 Accuracy: 0.0224 Time: 102.38432  | Val Loss: 4.7964 Accuracy: 0.0308
# Epoch: 35/120 Train Loss: 4.8379 Accuracy: 0.0227 Time: 102.38374  | Val Loss: 4.7351 Accuracy: 0.0326
# Epoch: 36/120 Train Loss: 4.8369 Accuracy: 0.0226 Time: 102.37962  | Val Loss: 4.7902 Accuracy: 0.0275
# Epoch: 37/120 Train Loss: 4.8331 Accuracy: 0.0223 Time: 102.39300  | Val Loss: 4.8051 Accuracy: 0.0321
# Epoch: 38/120 Train Loss: 4.8332 Accuracy: 0.0230 Time: 102.39371  | Val Loss: 4.7086 Accuracy: 0.0324
# Epoch: 39/120 Train Loss: 4.8324 Accuracy: 0.0228 Time: 102.40170  | Val Loss: 4.8961 Accuracy: 0.0292
# Epoch: 40/120 Train Loss: 4.8318 Accuracy: 0.0229 Time: 102.35679  | Val Loss: 4.8436 Accuracy: 0.0318
# Epoch: 41/120 Train Loss: 4.8325 Accuracy: 0.0226 Time: 102.40297  | Val Loss: 4.8674 Accuracy: 0.0273
# Epoch: 42/120 Train Loss: 4.8268 Accuracy: 0.0227 Time: 102.38203  | Val Loss: 5.0474 Accuracy: 0.0256
# Epoch: 43/120 Train Loss: 4.8304 Accuracy: 0.0223 Time: 102.38986  | Val Loss: 4.8335 Accuracy: 0.0295
# Epoch: 44/120 Train Loss: 4.8312 Accuracy: 0.0229 Time: 102.37024  | Val Loss: 5.1737 Accuracy: 0.0237
# Epoch: 45/120 Train Loss: 4.8311 Accuracy: 0.0238 Time: 102.38777  | Val Loss: 4.7110 Accuracy: 0.0307
# Epoch: 46/120 Train Loss: 4.8306 Accuracy: 0.0225 Time: 102.38074  | Val Loss: 4.8133 Accuracy: 0.0296
# Epoch: 47/120 Train Loss: 4.8262 Accuracy: 0.0223 Time: 102.37644  | Val Loss: 4.7671 Accuracy: 0.0318
# Epoch: 48/120 Train Loss: 4.8282 Accuracy: 0.0225 Time: 102.39816  | Val Loss: 4.9101 Accuracy: 0.0289
# Epoch: 49/120 Train Loss: 4.8286 Accuracy: 0.0219 Time: 102.38925  | Val Loss: 4.8312 Accuracy: 0.0332
# Epoch: 50/120 Train Loss: 4.8314 Accuracy: 0.0221 Time: 102.41691  | Val Loss: 4.6714 Accuracy: 0.0333
# Epoch: 51/120 Train Loss: 4.8268 Accuracy: 0.0222 Time: 102.37938  | Val Loss: 4.9062 Accuracy: 0.0314
# Epoch: 52/120 Train Loss: 4.8267 Accuracy: 0.0225 Time: 102.39868  | Val Loss: 4.7322 Accuracy: 0.0282
# Epoch: 53/120 Train Loss: 4.8264 Accuracy: 0.0226 Time: 102.40768  | Val Loss: 5.2213 Accuracy: 0.0218
# Epoch: 54/120 Train Loss: 4.8276 Accuracy: 0.0223 Time: 102.36038  | Val Loss: 4.8242 Accuracy: 0.0306
# Epoch: 55/120 Train Loss: 4.8265 Accuracy: 0.0226 Time: 102.40007  | Val Loss: 4.7458 Accuracy: 0.0235
# Epoch: 56/120 Train Loss: 4.8301 Accuracy: 0.0226 Time: 102.35821  | Val Loss: 4.7941 Accuracy: 0.0275
# Epoch: 57/120 Train Loss: 4.8288 Accuracy: 0.0224 Time: 102.38149  | Val Loss: 4.7434 Accuracy: 0.0296
# Epoch: 58/120 Train Loss: 4.8273 Accuracy: 0.0228 Time: 102.40578  | Val Loss: 4.6750 Accuracy: 0.0312
# Epoch: 59/120 Train Loss: 4.8247 Accuracy: 0.0227 Time: 102.38276  | Val Loss: 4.7145 Accuracy: 0.0338
# Epoch: 60/120 Train Loss: 4.8255 Accuracy: 0.0226 Time: 102.37829  | Val Loss: 5.0967 Accuracy: 0.0232
# Epoch: 61/120 Train Loss: 4.7823 Accuracy: 0.0247 Time: 102.39712  | Val Loss: 4.7017 Accuracy: 0.0344
# Epoch: 62/120 Train Loss: 4.7691 Accuracy: 0.0256 Time: 102.35201  | Val Loss: 4.7665 Accuracy: 0.0341
# Epoch: 63/120 Train Loss: 4.7677 Accuracy: 0.0254 Time: 102.36037  | Val Loss: 4.7243 Accuracy: 0.0335
# Epoch: 64/120 Train Loss: 4.7578 Accuracy: 0.0258 Time: 102.39389  | Val Loss: 4.8053 Accuracy: 0.0350
# Epoch: 65/120 Train Loss: 4.7586 Accuracy: 0.0255 Time: 102.38159  | Val Loss: 4.7803 Accuracy: 0.0341
# Epoch: 66/120 Train Loss: 4.7560 Accuracy: 0.0256 Time: 102.44663  | Val Loss: 4.7611 Accuracy: 0.0361
# Epoch: 67/120 Train Loss: 4.7516 Accuracy: 0.0272 Time: 102.35076  | Val Loss: 4.8238 Accuracy: 0.0325
# Epoch: 68/120 Train Loss: 4.7512 Accuracy: 0.0272 Time: 102.39480  | Val Loss: 4.7338 Accuracy: 0.0367
# Epoch: 69/120 Train Loss: 4.7506 Accuracy: 0.0270 Time: 102.37817  | Val Loss: 4.7960 Accuracy: 0.0340
# Epoch: 70/120 Train Loss: 4.7507 Accuracy: 0.0257 Time: 102.40281  | Val Loss: 4.8842 Accuracy: 0.0317
# Epoch: 71/120 Train Loss: 4.7524 Accuracy: 0.0262 Time: 102.37245  | Val Loss: 4.8078 Accuracy: 0.0319
# Epoch: 72/120 Train Loss: 4.7475 Accuracy: 0.0267 Time: 102.37964  | Val Loss: 4.8052 Accuracy: 0.0354
# Epoch: 73/120 Train Loss: 4.7469 Accuracy: 0.0270 Time: 102.37282  | Val Loss: 4.8273 Accuracy: 0.0323
# Epoch: 74/120 Train Loss: 4.7477 Accuracy: 0.0267 Time: 102.41829  | Val Loss: 4.8247 Accuracy: 0.0321
# Epoch: 75/120 Train Loss: 4.7479 Accuracy: 0.0267 Time: 102.39655  | Val Loss: 4.6801 Accuracy: 0.0381
# Epoch: 76/120 Train Loss: 4.7422 Accuracy: 0.0261 Time: 102.38668  | Val Loss: 4.8434 Accuracy: 0.0349
# Epoch: 77/120 Train Loss: 4.7374 Accuracy: 0.0266 Time: 102.38171  | Val Loss: 4.7287 Accuracy: 0.0345
# Epoch: 78/120 Train Loss: 4.7422 Accuracy: 0.0255 Time: 102.37063  | Val Loss: 4.7689 Accuracy: 0.0365
# Epoch: 79/120 Train Loss: 4.7366 Accuracy: 0.0273 Time: 102.35986  | Val Loss: 4.7492 Accuracy: 0.0361
# Epoch: 80/120 Train Loss: 4.7368 Accuracy: 0.0265 Time: 102.34857  | Val Loss: 4.7954 Accuracy: 0.0339
# Epoch: 81/120 Train Loss: 4.7395 Accuracy: 0.0261 Time: 102.39950  | Val Loss: 4.8160 Accuracy: 0.0353
# Epoch: 82/120 Train Loss: 4.7393 Accuracy: 0.0266 Time: 102.40213  | Val Loss: 4.7313 Accuracy: 0.0384
# Epoch: 83/120 Train Loss: 4.7358 Accuracy: 0.0267 Time: 102.36956  | Val Loss: 4.7975 Accuracy: 0.0360
# Epoch: 84/120 Train Loss: 4.7394 Accuracy: 0.0267 Time: 102.35035  | Val Loss: 4.8151 Accuracy: 0.0336
# Epoch: 85/120 Train Loss: 4.7363 Accuracy: 0.0274 Time: 102.35318  | Val Loss: 4.8121 Accuracy: 0.0384
# Epoch: 86/120 Train Loss: 4.7372 Accuracy: 0.0263 Time: 102.34288  | Val Loss: 4.7532 Accuracy: 0.0355
# Epoch: 87/120 Train Loss: 4.7357 Accuracy: 0.0264 Time: 102.34974  | Val Loss: 4.7419 Accuracy: 0.0366
# Epoch: 88/120 Train Loss: 4.7344 Accuracy: 0.0273 Time: 102.36006  | Val Loss: 4.7412 Accuracy: 0.0353
# Epoch: 89/120 Train Loss: 4.7288 Accuracy: 0.0278 Time: 102.37089  | Val Loss: 4.7621 Accuracy: 0.0361
# Epoch: 90/120 Train Loss: 4.7313 Accuracy: 0.0272 Time: 102.37091  | Val Loss: 4.7883 Accuracy: 0.0357
# Early stop at epoch 90!
# #Parameter: 21379592 Accuracy: 0.0332

# %%
import torchvision

# %%
import torchvision.transforms.v2


torchvision.transforms.v2.
# Out:
#   Cell In[7], line 4
#     torchvision.transforms.v2.
#                               ^
# SyntaxError: invalid syntax

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.figure(figsize=(16,5))
images_per_class = 5
num_classes = 15

for target_class in range(num_classes):
    idxs = [idx  for idx, target  in enumerate(train_dataset.targets) if target == target_class]
    idxs = idxs[:images_per_class]
    for i, idx in enumerate(idxs):
        plt_idx = i * num_classes + target_class + 1
        plt.subplot(images_per_class, num_classes, plt_idx)
        image,_ = train_dataset[idx]
        plt.imshow(image)
        plt.axis("off")
        if i == 0:
            plt.title(f"{train_dataset.classes[target_class][0]}", fontsize = "x-small")
plt.show()
